# %% [markdown]
# Show the effect of a change to controller parameters.
#
# The source code in the `controller/DISCON_tweaked` folder has been altered and recompiled and then used in the updated simulation.

# %%
import pandas as pd
import numpy as np
from helpers import read_out

# %%
df1 = read_out("../runs/baseline/seed03/5MW_Land_DLL_WTurb.out")
df2 = read_out("../runs/controller_tweaked/seed03/5MW_Land_DLL_WTurb.out")

# %%
columns = ["Wind1VelX", "GenTq", "GenSpeed", "BlPitchC1"]
ax = df1[columns].loc[:].plot(subplots=True, color='C0', figsize=(8, 8))
df2[columns].loc[:].plot(subplots=True, ax=ax, color='C1');
